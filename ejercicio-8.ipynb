# %% [markdown]
# # Tecnología

# %% [markdown]
# Tecnología. Se preguntó a 30 jóvenes cuántas horas dedicaban cada día a navegar en internet (el
# tiempo que dedican a sesiones de chat y a las redes sociales quedan incluidos). Los resultados
# son los siguientes:

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Columna 1</th>
# <th>Columna 2</th>
# <th>Columna 3</th>
# <th>Columna 4</th>
# <th>Columna 5</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2.5</td>
# <td>4.5</td>
# <td>5.8</td>
# <td>2.2</td>
# <td>5.7</td>
# </tr>
# <tr>
# <td>5.3</td>
# <td>4.0</td>
# <td>0.9</td>
# <td>2.5</td>
# <td>2.3</td>
# </tr>
# <tr>
# <td>3.2</td>
# <td>4.9</td>
# <td>2.7</td>
# <td>3.7</td>
# <td>3.8</td>
# </tr>
# <tr>
# <td>4.9</td>
# <td>2.8</td>
# <td>3.6</td>
# <td>4.2</td>
# <td>3.1</td>
# </tr>
# <tr>
# <td>7.2</td>
# <td>1.9</td>
# <td>5.9</td>
# <td>3.3</td>
# <td>2.9</td>
# </tr>
# <tr>
# <td>1.1</td>
# <td>1.7</td>
# <td>2.6</td>
# <td>3.1</td>
# <td>4.4</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # a. ¿Qué tipo de datos se maneja en este problema?

# %% [markdown]
# Se manejan datos numéricos continuos. Los datos representan las horas que los jóvenes dedican a navegar en Internet cada día.

# %% [markdown]
# # b. Construye la distribución de frecuencias correspondiente.

# %% [markdown]
# <table>
#   <tr>
#     <th>Clase</th>
#     <th>X</th>
#     <th>F</th>
#     <th>Fa</th>
#     <th>Fr (%)</th>
#     <th>Fra (%)</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>0.9 - 1.95</td>
#     <td>4</td>
#     <td>4</td>
#     <td>13.33%</td>
#     <td>13.33%</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>1.69 - 3.01</td>
#     <td>8</td>
#     <td>12</td>
#     <td>26.66%</td>
#     <td>39.99%</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>3.02 - 4.07</td>
#     <td>7</td>
#     <td>19</td>
#     <td>23.33%</td>
#     <td>63.32%</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>4.08 - 5.13</td>
#     <td>6</td>
#     <td>25</td>
#     <td>20%</td>
#     <td>83.22%</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>5.14 - 6.19</td>
#     <td>4</td>
#     <td>29</td>
#     <td>13.33%</td>
#     <td>96.65%</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>6.20 - 7.25</td>
#     <td>1</td>
#     <td>30</td>
#     <td>3.33%</td>
#     <td>100%</td>
#   </tr>
# </table>

# %% [markdown]
# # c. Traza un histograma y una ojiva.

# %% [markdown]
# # Histograma

# %%
import matplotlib.pyplot as plt
print("Setup terminado")
# Out:
# Setup terminado

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

marcas_clase = ["0.9-1.95", "1.69-3.01", "3.02-4.07", "4.08-5.13", "5.14-6.19", "6.20-7.25"]
frecuencia = [4, 9, 8, 6, 2, 1]
marcas_textos = ["1", "2", "3","4", "5", "6"]

plt.bar(marcas_clase, frecuencia,
        width=0.8,
        edgecolor="k",
        color=["#740505", "#740560", "#B227C6", "#9363D3", "#6372D3", "#63B1D3"])
plt.xticks(marcas_clase, marcas_textos, fontsize= 15, rotation= 45)
plt.title("HISTOGRAMA", fontsize=40)
plt.xlabel("Marcas de clase", fontsize=25)
plt.ylabel("Frecuencia absoluta", fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# # Ojiva

# %%
plt.figure(figsize = (12, 6)) # Ancho, largo del grafico
marcas_clase = [1, 2, 3, 4, 5, 6]#Datos del eje X
# frecuencia =[0.5, 0.15, 0.20, 0.20, 0.10, 0.30,] #Datos del eje Y
frecuencia =[13.33, 39.99, 63.32, 83.22, 96.65, 100] #Datos del eje Y

# Ajuste en las listas para generar el poligino de frecuencia
datos_x = [0] + marcas_clase 
datos_y = [0] + frecuencia 

#Leyendas para las marcas de clase
marcas_textos = ["1", "2", "3","4", "5", "6"]


# Poligono de frecuencia con:
# - Estilo de line puntedo ( linewidth = 5, color = "r", linestyle = ":"). https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# - Marcador con forma triangular (marker = "v"). https://matplotlib.org/stable/api/markers_api.html
plt.plot(datos_x, datos_y,
        linewidth = 5, color = "r", linestyle = ":",
        marker = "v", markersize = 15, markeredgecolor = "b", markerfacecolor = "y")

plt.xticks(marcas_clase , marcas_textos, fontsize= 15, rotation= 45)# Cambio de las marcas de clese del eje x de número a texto.
plt.title("Ojiva", fontsize = 40) # Titulo
plt.xlabel("Marcas de clase", fontsize = 25) # Etiqueta eje X
plt.ylabel("Frecuencia relativa", fontsize = 25) # Etiqueta eje Y
plt.grid(True)#Cuatricula
plt.show()#Se muestra gráfica en pantalla

# %% [markdown]
# # d. ¿A qué conclusiones llegaron tú y tus compañeros?

# %% [markdown]
# - El intervalo con la mayor frecuencia absoluta es "1.69 - 3.01", con una frecuencia de 8 jóvenes.
# - La mayoría de los jóvenes (63.32%) se encuentran en los intervalos "3.02 - 4.07" y "4.08 - 5.13", lo que indica que pasan entre 3 y 5 horas navegando en Internet
# - Los intervalos "0.9 - 1.95" y "5.14 - 6.19" tienen la menor frecuencia absoluta, con 4 jóvenes cada uno.
# - La frecuencia relativa acumulada indica que aproximadamente el 83.22% de los jóvenes navegan en Internet durante 4 horas o menos al día.
# - El último intervalo "6.20 - 7.25" tiene la menor frecuencia absoluta y relativa, lo que sugiere que solo un joven pasa más de 6 horas navegando en Internet.

# %% [markdown]
# # ¿Crees que es recomendable pasar tanto tiempo frente a una computadora?

# %% [markdown]
# No aun que existen muchos beneficios como el acceso a información, la comunicación, el trabajo y el entretenimiento. Sin embargo tambien puede traer efectos negativos como sedentarismo, fatiga visual, problemas posturales y aislamiento social.
